# %%
import sys, os
sys.path.append("..")  # ensures notebook can see src folder

from src.escalation import EscalationAgent

agent = EscalationAgent()

# Sample test cases
intents = [
    "delivery_delay",
    "praise",
    "product_query",
    "return_refund",
    "billing_problem",
    "account_access",
    "complaint_unresolved",
    "order_issue",
    "unknown_intent"
]

for intent in intents:
    decision, reason = agent.decide(intent)
    print(f"Intent: {intent}\nDecision: {decision}\nReason: {reason}\n{'-'*60}")
# Out:
# Intent: delivery_delay
# Decision: auto
# Reason: Routine delivery delays can be auto-handled with tracking info.
# ------------------------------------------------------------
# Intent: praise
# Decision: auto
# Reason: Positive feedback can be acknowledged automatically.
# ------------------------------------------------------------
# Intent: product_query
# Decision: auto
# Reason: Simple product queries can be answered automatically.
# ------------------------------------------------------------
# Intent: return_refund
# Decision: auto
# Reason: Return/refund requests can be initiated automatically.
# ------------------------------------------------------------
# Intent: billing_problem
# Decision: escalate
# Reason: Billing issues require secure handling by human support.
# ------------------------------------------------------------
# Intent: account_access
# Decision: escalate
# Reason: Account access problems involve sensitive data and must be escalated.
# ------------------------------------------------------------
# Intent: complaint_unresolved
# Decision: escalate
# Reason: Unresolved complaints need human intervention to ensure resolution.
# ------------------------------------------------------------
# Intent: order_issue
# Decision: escalate
# Reason: Wrong or missing items often need manual support to resolve.
# ------------------------------------------------------------
# Intent: unknown_intent
# Decision: escalate
# Reason: Unknown intent — escalated by default for safety.
# ------------------------------------------------------------
