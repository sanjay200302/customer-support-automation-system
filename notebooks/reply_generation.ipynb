# %%
import sys
import os

# Add project root to Python path
project_root = os.path.abspath("..")   # adjust if notebook is inside /notebooks
sys.path.append(project_root)

# Now you can import from src
from src.reply_agent import ReplyAgent

# %%
import sys, os
sys.path.append("..")  # ensures notebook can see src folder

from src.reply_agent import ReplyAgent

# Initialize agent
agent = ReplyAgent()

# Sample test cases
samples = [
    ("delivery_delay", "My package is late again!", "auto"),
    ("order_issue", "I received the wrong item.", "auto"),
    ("billing_problem", "I was charged twice for my order.", "escalate"),
    ("account_access", "I can’t log into my account.", "escalate"),
    ("complaint_unresolved", "I’ve contacted support 3 times and nothing is fixed.", "escalate"),
    ("praise", "Amazon service is amazing!", "auto"),
    ("product_query", "Does this laptop support Windows 11?", "auto"),
    ("return_refund", "I want to return my headphones.", "auto"),
]

for intent, text, decision in samples:
    reply = agent.generate(intent, text, decision)
    print(f"Intent: {intent}\nCustomer: {text}\nEscalation: {decision}\nReply: {reply}\n{'-'*60}")
# Out:
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# Intent: delivery_delay
# Customer: My package is late again!
# Escalation: auto
# Reply: We’re sorry your package is delayed. Please DM us your order ID so we can assist.
# ------------------------------------------------------------
# Intent: order_issue
# Customer: I received the wrong item.
# Escalation: auto
# Reply: We understand you’re facing an order issue. Kindly share your order details via DM.
# ------------------------------------------------------------
# Intent: billing_problem
# ...
